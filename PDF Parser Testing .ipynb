# %%
cd Downloads
# Out:
# [WinError 2] The system cannot find the file specified: 'Downloads'
# C:\Users\Anura\OneDrive\Amaris.AI Product & Project Mgmt Internship\Testing

# %%
# !pip install -r requirements.txt

# %%
cd "C:\Users\Anura\OneDrive\Amaris.AI Product & Project Mgmt Internship\Testing"
# Out:
# C:\Users\Anura\OneDrive\Amaris.AI Product & Project Mgmt Internship\Testing

# %%
# !pip install frontend

# %%
# !python getheader.py "Personal Data Protection (Appeal) Regulations 2021.pdf"
# Out:
# No TOC found
# ...

# %%
# !python --version
# Out:
# Python 3.9.12

# %%
# !pip install pymupdf

# %%
import fitz

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      1.0.0
# aiofiles                     0.8.0
# anyio                        3.6.1
# arango                       0.2.1
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asgiref                      3.5.2
# asttokens                    2.0.5
# astunparse                   1.6.3
# attrs                        21.4.0
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bleach                       4.1.0
# blis                         0.7.7
# cachetools                   5.2.0
# Camelot                      12.6.29
# camelot-py                   0.9.0
# catalogue                    2.0.7
# certifi                      2022.5.18.1
# cffi                         1.15.0
# chardet                      4.0.0
# charset-normalizer           2.0.12
# ci-info                      0.2.0
# click                        8.1.3
# ...

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 7655-7F6C
#
#  Directory of C:\Users\Anura\OneDrive\Amaris.AI Product & Project Mgmt Internship\Testing
#
# 23/06/2022  13:25    <DIR>          .
# 21/06/2022  09:09    <DIR>          ..
# 21/06/2022  17:40    <DIR>          .ipynb_checkpoints
# 21/06/2022  17:36    <DIR>          99 Privacy Breaches to Beware Of_nodrm (1)
# 20/06/2022  11:20         5,025,162 99 Privacy Breaches to Beware Of_nodrm (1).pdf
# 23/06/2022  13:23    <DIR>          Big Data Governance An Emerging Imperative (Soares, Sunil) (z-lib.org)
# 20/06/2022  11:20         5,950,674 Big Data Governance An Emerging Imperative (Soares, Sunil) (z-lib.org).pdf
# 20/06/2022  11:20         4,399,124 Book_DataPrivacyFoundationsNewDevel.pdf
# 15/06/2022  17:17            15,531 Codes For Testing.docx
# 20/06/2022  11:20         7,601,750 Dennedy2014_Book_ThePrivacyEngineerSManifesto.pdf
# 16/06/2022  14:20         1,765,322 Final Testing.ipynb
# ...
